# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# Data Collection & Analysis

# %%
# loading the Data from csv file to a Pandas DataFrame
df = pd.read_csv('E:/PremiumPrediction/notebook/data/insurance.csv')

# %%
# first 5 row of the dataframe
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# numbers of rows and columns
df.shape
# Out:
# (1338, 7)

# %%
# getting some informations about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# Categorical Features:
# - Sex
# - Smoker
# - Region

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %% [markdown]
# Data Analysis

# %%
# Statistical Measures of the Dataset
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
# Distribution of Age value
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['age'])
plt.title('Age Distribution')
plt.show()

# %%
# Gender column
plt.figure(figsize=(6,6))
sns.countplot(x='sex', data=df)
plt.title('Sex Distribution')
plt.show()

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
# BMI Distribution
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['bmi'])
plt.title('BMI Distribution')
plt.show()

# %% [markdown]
# Normal BMI Range --> 18.5 to 24.9

# %%
# Children column
plt.figure(figsize=(6,6))
sns.countplot(x='children', data=df)
plt.title('Children')
plt.show()

# %%
df['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
# Smoker column
plt.figure(figsize=(6,6))
sns.countplot(x='smoker', data=df)
plt.title('Smoker')
plt.show()

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
# Region column
plt.figure(figsize=(6,6))
sns.countplot(x='region', data=df)
plt.title('region')
plt.show()

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
# Distribution of Expenses value
plt.figure(figsize=(6,6))
sns.displot(df['expenses'])
plt.title('Expenses Distribution')
plt.show()

# %% [markdown]
# Data pre-processing

# %% [markdown]
# Encoding the categorical features

# %%
# encoding sex column
df.replace({'sex':{'male':0, 'female':1}}, inplace=True)

#encoding smoker column
df.replace({'smoker':{'yes':0, 'no':1}}, inplace=True)

#encoding region column
df.replace({'region':{'southeast':0, 'southwest':1, 'northeast':2, 'northwest':3}}, inplace=True)
# Out:
# C:\Users\erjay\AppData\Local\Temp\ipykernel_2848\957105879.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'sex':{'male':0, 'female':1}}, inplace=True)
# C:\Users\erjay\AppData\Local\Temp\ipykernel_2848\957105879.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'smoker':{'yes':0, 'no':1}}, inplace=True)
# C:\Users\erjay\AppData\Local\Temp\ipykernel_2848\957105879.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'region':{'southeast':0, 'southwest':1, 'northeast':2, 'northwest':3}}, inplace=True)

# %% [markdown]
# Splitting the Features and Target

# %%
x = df.drop(columns='expenses', axis=1)
y = df['expenses']

# %%
print(x)
# Out:
#       age  sex   bmi  children  smoker  region
# 0      19    1  27.9         0       0       1
# 1      18    0  33.8         1       1       0
# 2      28    0  33.0         3       1       0
# 3      33    0  22.7         0       1       3
# 4      32    0  28.9         0       1       3
# ...   ...  ...   ...       ...     ...     ...
# 1333   50    0  31.0         3       1       3
# 1334   18    1  31.9         0       1       2
# 1335   18    1  36.9         0       1       0
# 1336   21    1  25.8         0       1       1
# 1337   61    1  29.1         0       0       3
#
# [1338 rows x 6 columns]

# %%
print(y)
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %% [markdown]
# Splitting the data into Training data and Testing data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (1338, 6) (1070, 6) (268, 6)

# %% [markdown]
# Model Training

# %% [markdown]
# Linear Regression

# %%
# Loading the Linear Regression model
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model Evaluation

# %%
# prediction on training data
training_data_prediction = regressor.predict(x_train)

# %%
# R squared value
r2_train = metrics.r2_score(y_train, training_data_prediction)
print('R squared vale : ', r2_train)
# Out:
# R squared vale :  0.7515233180624388

# %%
# prediction on test data
test_data_prediction = regressor.predict(x_test)

# %%
# R squared value
r2_test = metrics.r2_score(y_test, test_data_prediction)
print('R squared value: ', r2_test)
# Out:
# R squared value:  0.7447382074449773

# %% [markdown]
# # Building a Predictive System

# %%
input_data = (31,1,25.7,0,1,0)

# changing input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = regressor.predict(input_data_reshaped)
print(prediction)

print('The insurance cost is USD ', prediction[0])
# Out:
# [3746.10714209]
# The insurance cost is USD  3746.107142091616
# e:\PremiumPrediction\venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
